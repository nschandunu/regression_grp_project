# %%
import pandas as pd

# %%
# Load the dataset (it will look for it in the same folder!)
df = pd.read_csv("houses.csv")

# %%
# 1. Define features (X) and target (y)
features = ["size", "rooms", "age"]
X = df[features]
y = df["price"]

# %%
# 2. Split into Train (first 150) and Test (last 50)
X_train = X.iloc[:150]
y_train = y.iloc[:150]

X_test = X.iloc[150:]
y_test = y.iloc[150:]

print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
